# %%
from numpy import *
from pandas import *
from matplotlib import pyplot, rcParams
from seaborn import *
# %matplotlib inline
set(style='darkgrid')

# %% [markdown]
# # Bar Diagram or Bar Graph (For Qualitative/Categorical/Nominal Data)

# %%
# Creating the Categorical Nominal Data
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}
courses = list(data.keys())                  # Bar Chart Used for Discrete Distribution
values = list(data.values())
  
fig = pyplot.figure(figsize = (10, 5))
 
# Creating the bar plot
pyplot.bar(courses, values, color ='maroon',
        width = 0.4)
 
pyplot.xlabel("Courses offered")
pyplot.ylabel("No. of students enrolled Frequency")
pyplot.title("Students enrolled in different courses")
pyplot.show()

# %%
#!python
# -*- coding: utf-8 -*-#
#
# Imports
import matplotlib.pyplot as pyplot
import numpy
import collections

data = """
Jan
Feb
Mar
Apr
May
Jun
Jul
Aug
Sep
Oct
Nov
Dec
"""
months = data.split()

data = [6, 6, 6, 6, 6, 6, 6, 6, 1, 1, 6, 1, 6, 2, 1, 1, 6, 1, 6, 2, 1, 6, 6, 2, 1, 2, 1, 6, 2, 1, 1, 6, 1, 6, 3, 3, 3, 3, 3, 1, 2, 1, 3, 3, 3, 3, 3, 1, 2, 1, 3, 3, 3, 3, 3, 1, 2, 1, 6, 2, 1, 10,
        6, 12, 9, 3, 3, 3, 3, 3, 1, 2, 1, 7, 8, 9, 10, 10, 11, 12, 11, 3, 3, 3, 3, 3, 1, 12, 12, 6, 2, 5, 10, 6, 12, 9, 3, 3, 3, 3, 5, 1, 2, 1, 7, 8, 9, 10, 10, 11, 12, 11, 5, 5, 3, 3, 3, 1, 12, 12]

c = collections.Counter(data)
c = sorted(c.items())
months_num = [i[0] for i in c]
month_names = [months[i[0]-1] for i in c]
freq = [i[1] for i in c]

print(c)
print(months)
print(freq)
f, ax = pyplot.subplots()


pyplot.bar(months_num, freq)
pyplot.title("Job Request per month") # Bar Chart Used for Discrete Distribution
pyplot.xlabel("Months")
pyplot.ylabel("Frequency")
ax.set_xticks(range(1, 13))
ax.set_xticklabels(months)

pyplot.show()
# Out:
# [(1, 25), (2, 12), (3, 32), (5, 4), (6, 21), (7, 2), (8, 2), (9, 4), (10, 6), (11, 4), (12, 8)]
# ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
# [25, 12, 32, 4, 21, 2, 2, 4, 6, 4, 8]

# %%
# set width of bar
barWidth = 0.25
fig = pyplot.subplots(figsize =(12, 8))
 
# set height of bar
IT = [12, 30, 1, 8, 22]
ECE = [28, 6, 16, 5, 10]
CSE = [29, 3, 24, 25, 17]
 
# Set position of bar on X axis
br1 = numpy.arange(len(IT))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
 
# Make the plot
pyplot.bar(br1, IT, color ='r', width = barWidth,
        edgecolor ='grey', label ='IT')
pyplot.bar(br2, ECE, color ='g', width = barWidth,
        edgecolor ='grey', label ='ECE')
pyplot.bar(br3, CSE, color ='b', width = barWidth,
        edgecolor ='grey', label ='CSE')
 
# Adding Xticks
pyplot.xlabel('Branch', fontweight ='bold', fontsize = 15)
pyplot.ylabel('Frequency of Students passed', fontweight ='bold', fontsize = 15)
pyplot.xticks([r + barWidth for r in range(len(IT))],
        ['2015', '2016', '2017', '2018', '2019'])
 
pyplot.legend()
pyplot.show()

# %% [markdown]
# # Pie Diagram (For Qualitative/Categorical/Nominal Data)

# %%
# Creating dataset
cars = ['AUDI', 'BMW', 'FORD',
        'TESLA', 'JAGUAR', 'MERCEDES']
 
data = [23, 17, 35, 29, 12, 41]
 
# Creating explode data
explode = (0.1, 0.0, 0.2, 0.3, 0.0, 0.0)
 
# Creating color parameters
colors = ( "orange", "cyan", "brown",
          "grey", "indigo", "beige")
 
# Wedge properties
wp = { 'linewidth' : 1, 'edgecolor' : "green" }
 
# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*numpy.sum(allvalues))
    return "{:.1f}%\n({:d} g)".format(pct, absolute)
 
# Creating plot
fig, ax = pyplot.subplots(figsize =(12, 9))
wedges, texts, autotexts = ax.pie(data,
                                  autopct = lambda pct: func(pct, data),
                                  explode = explode,
                                  labels = cars,
                                  shadow = True,
                                  colors = colors,
                                  startangle = 90,
                                  wedgeprops = wp,
                                  textprops = dict(color ="magenta"))
 
# Adding legend
ax.legend(wedges, cars,
          title ="Cars",
          loc ="center left",
          bbox_to_anchor =(1, 0, 0.5, 1))
 
pyplot.setp(autotexts, size = 9, weight ="bold")
ax.set_title("Customizing pie chart")
 
# show plot
pyplot.show()

# %% [markdown]
# # Histogram or Column Diagram Alongwith Frequency Polygon (For Quantitative/Numerical Data)

# %%
# generate a sample of random gaussians
rcParams["figure.figsize"] = (15,8)
from numpy.random import seed
from numpy.random import randn
from matplotlib import pyplot
# seed the random number generator
seed(1)
# generate univariate observations
data = 20 * randn(25000) + 70
# histogram of generated data
a,bins,c=pyplot.hist(data, bins=25, density=False, color='b')
l=list(bins)
l.insert(0,0)
l.insert(len(bins)+1,bins[len(bins)-1])
mid=[]
for i in range(len(l)-1):
    ele=(l[i]+l[i+1])/2
    mid.append(ele)
x=list(a)
x.insert(0,0)
x.insert(len(a)+1,0)
pyplot.plot(mid,x,'go--')
pyplot.xlabel("X axis is for Histogram Bar Age Group Interval", fontweight ='bold')
pyplot.ylabel("Y axis is for Frequency of Each Histogram Bar Age Group Interval", fontweight ='bold')
pyplot.title("Histogram Frequency Distribution of Age", fontweight ='bold')
pyplot.show()
